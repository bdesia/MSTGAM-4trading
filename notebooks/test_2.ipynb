# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

from main import DCTrader, Backtest, DCTracker
from trainer import GATrainer, PSOTrainer

# %%
from strategies import St1, St2, St3, St4, St5, St6, St7, St8

ticker = 'test'

# thresholds = [0.00098, 0.0022, 0.0048, 0.0072, 0.0098, 0.0122, 0.0155, 0.017, 0.02, 0.0255]
# strategies = [St1, St2, St3, St4, St5, St6, St7, St8]

thresholds = [0.06]
strategies = [St1]

# Modo entrenamiento (precomputa estados)
trader = DCTrader(
    ticker=ticker,
    thresholds=thresholds,
    strategies=strategies,
    is_train=True,
    start_date='2020-01-01',
    end_date='2024-01-01'
)

print(f"Trader creado para {ticker}")
print(f"Thresholds: {thresholds}")
print(f"Datos cargados: {len(trader.prices)} días")
# Out:
# test: 17 loaded days | 2020-01-01 to 2020-01-17
# Trader creado para test
# Thresholds: [0.06]
# Datos cargados: 17 días

# %%
total_weights = len(trader.combination_matrix)
total_weights
# Out:
# 1

# %%
trader.prices
# Out:
# 0      99.9
# 1      98.0
# 2      97.0
# 3      94.0
# 4      98.0
# 5     102.0
# 6     104.0
# 7     103.0
# 8     109.0
# 9     110.0
# 10    107.0
# 11    105.0
# 12     96.0
# 13     94.0
# 14     96.0
# 15     94.0
# 16     90.0
# Name: Close, dtype: float64

# %%
trader.backtest([total_weights])
# Out:
# current price: 99.9
# current time: 0
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 99.900000
# Time of extreme (t_ext): 0
# Theoretical DCC (p_dcc_star): 105.894000
# Initial extreme cycle: 99.900000
# Last DCC time: 0
# Current OS length: 0
# Last DC duration: 0
# Is DCC now?: False
#
# === Statistics ===
# DC events: 0
# OS events: 0
# Total DC time: 0
# Total OS time: 0
#
# OSV DT (0): []
# OSV UT (0): []
# TMV DT (0): []
# TMV UT (0): []
#
# Recent trends: []
# Recent OS flags: []
# =============================
# 0
#
# current price: 98.0
# current time: 1
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 98.000000
# Time of extreme (t_ext): 1
# Theoretical DCC (p_dcc_star): 105.894000
# Initial extreme cycle: 99.900000
# Last DCC time: 0
# Current OS length: 1
# Last DC duration: 0
# Is DCC now?: False
#
# === Statistics ===
# DC events: 0
# OS events: 0
# Total DC time: 0
# Total OS time: 0
#
# OSV DT (0): []
# OSV UT (0): []
# TMV DT (0): []
# TMV UT (0): []
#
# Recent trends: []
# Recent OS flags: []
# =============================
# 0
#
# current price: 97.0
# current time: 2
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 97.000000
# Time of extreme (t_ext): 2
# Theoretical DCC (p_dcc_star): 105.894000
# Initial extreme cycle: 99.900000
# Last DCC time: 0
# Current OS length: 2
# Last DC duration: 0
# Is DCC now?: False
#
# === Statistics ===
# DC events: 0
# OS events: 0
# Total DC time: 0
# Total OS time: 0
#
# OSV DT (0): []
# OSV UT (0): []
# TMV DT (0): []
# TMV UT (0): []
#
# Recent trends: []
# Recent OS flags: []
# =============================
# 0
#
# current price: 94.0
# current time: 3
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 94.000000
# Time of extreme (t_ext): 3
# Theoretical DCC (p_dcc_star): 105.894000
# Initial extreme cycle: 99.900000
# Last DCC time: 0
# Current OS length: 3
# Last DC duration: 0
# Is DCC now?: False
#
# === Statistics ===
# DC events: 0
# OS events: 0
# Total DC time: 0
# Total OS time: 0
#
# OSV DT (0): []
# OSV UT (0): []
# TMV DT (0): []
# TMV UT (0): []
#
# Recent trends: []
# Recent OS flags: []
# =============================
# 0
#
# current price: 98.0
# current time: 4
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 94.000000
# Time of extreme (t_ext): 3
# Theoretical DCC (p_dcc_star): 105.894000
# Initial extreme cycle: 99.900000
# Last DCC time: 0
# Current OS length: 3
# Last DC duration: 0
# Is DCC now?: False
#
# === Statistics ===
# DC events: 0
# OS events: 0
# Total DC time: 0
# Total OS time: 0
#
# OSV DT (0): []
# OSV UT (0): []
# TMV DT (0): []
# TMV UT (0): []
#
# Recent trends: []
# Recent OS flags: []
# =============================
# 0
#
# current price: 102.0
# current time: 5
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 102.000000
# Time of extreme (t_ext): 5
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 0
# Last DC duration: 2
# Is DCC now?: True
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 104.0
# current time: 6
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 104.000000
# Time of extreme (t_ext): 6
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 1
# Last DC duration: 2
# Is DCC now?: False
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 103.0
# current time: 7
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 104.000000
# Time of extreme (t_ext): 6
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 1
# Last DC duration: 2
# Is DCC now?: False
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 109.0
# current time: 8
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 109.000000
# Time of extreme (t_ext): 8
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 2
# Last DC duration: 2
# Is DCC now?: False
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 110.0
# current time: 9
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 110.000000
# Time of extreme (t_ext): 9
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 3
# Last DC duration: 2
# Is DCC now?: False
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 107.0
# current time: 10
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 110.000000
# Time of extreme (t_ext): 9
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 3
# Last DC duration: 2
# Is DCC now?: False
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 105.0
# current time: 11
# === DCTracker State ===
# Theta: 0.0600
# Current trend: uptrend
# Current extreme price (p_ext): 110.000000
# Time of extreme (t_ext): 9
# Theoretical DCC (p_dcc_star): 95.880000
# Initial extreme cycle: 94.000000
# Last DCC time: 5
# Current OS length: 3
# Last DC duration: 2
# Is DCC now?: False
#
# === Statistics ===
# DC events: 1
# OS events: 1
# Total DC time: 2
# Total OS time: 3
#
# OSV DT (1): [0.6129]
# OSV UT (0): []
# TMV DT (1): [0.3504]
# TMV UT (0): []
#
# Recent trends: ['downtrend']
# Recent OS flags: [True]
# =============================
# 0
#
# current price: 96.0
# current time: 12
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 96.000000
# Time of extreme (t_ext): 12
# Theoretical DCC (p_dcc_star): 101.760000
# Initial extreme cycle: 110.000000
# Last DCC time: 12
# Current OS length: 0
# Last DC duration: 3
# Is DCC now?: True
#
# === Statistics ===
# DC events: 2
# OS events: 2
# Total DC time: 5
# Total OS time: 7
#
# OSV DT (1): [0.6129]
# OSV UT (1): [0.0209]
# TMV DT (1): [0.3504]
# TMV UT (1): [0.3546]
#
# Recent trends: ['downtrend', 'uptrend']
# Recent OS flags: [True, True]
# =============================
# 0
#
# current price: 94.0
# current time: 13
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 94.000000
# Time of extreme (t_ext): 13
# Theoretical DCC (p_dcc_star): 101.760000
# Initial extreme cycle: 110.000000
# Last DCC time: 12
# Current OS length: 1
# Last DC duration: 3
# Is DCC now?: False
#
# === Statistics ===
# DC events: 2
# OS events: 2
# Total DC time: 5
# Total OS time: 7
#
# OSV DT (1): [0.6129]
# OSV UT (1): [0.0209]
# TMV DT (1): [0.3504]
# TMV UT (1): [0.3546]
#
# Recent trends: ['downtrend', 'uptrend']
# Recent OS flags: [True, True]
# =============================
# 0
#
# current price: 96.0
# current time: 14
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 94.000000
# Time of extreme (t_ext): 13
# Theoretical DCC (p_dcc_star): 101.760000
# Initial extreme cycle: 110.000000
# Last DCC time: 12
# Current OS length: 1
# Last DC duration: 3
# Is DCC now?: False
#
# === Statistics ===
# DC events: 2
# OS events: 2
# Total DC time: 5
# Total OS time: 7
#
# OSV DT (1): [0.6129]
# OSV UT (1): [0.0209]
# TMV DT (1): [0.3504]
# TMV UT (1): [0.3546]
#
# Recent trends: ['downtrend', 'uptrend']
# Recent OS flags: [True, True]
# =============================
# 0
#
# current price: 94.0
# current time: 15
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 94.000000
# Time of extreme (t_ext): 13
# Theoretical DCC (p_dcc_star): 101.760000
# Initial extreme cycle: 110.000000
# Last DCC time: 12
# Current OS length: 1
# Last DC duration: 3
# Is DCC now?: False
#
# === Statistics ===
# DC events: 2
# OS events: 2
# Total DC time: 5
# Total OS time: 7
#
# OSV DT (1): [0.6129]
# OSV UT (1): [0.0209]
# TMV DT (1): [0.3504]
# TMV UT (1): [0.3546]
#
# Recent trends: ['downtrend', 'uptrend']
# Recent OS flags: [True, True]
# =============================
# 0
#
# current price: 90.0
# current time: 16
# === DCTracker State ===
# Theta: 0.0600
# Current trend: downtrend
# Current extreme price (p_ext): 90.000000
# Time of extreme (t_ext): 16
# Theoretical DCC (p_dcc_star): 101.760000
# Initial extreme cycle: 110.000000
# Last DCC time: 12
# Current OS length: 2
# Last DC duration: 3
# Is DCC now?: False
#
# === Statistics ===
# DC events: 2
# OS events: 2
# Total DC time: 5
# Total OS time: 7
#
# OSV DT (1): [0.6129]
# OSV UT (1): [0.0209]
# TMV DT (1): [0.3504]
# TMV UT (1): [0.3546]
#
# Recent trends: ['downtrend', 'uptrend']
# Recent OS flags: [True, True]
# =============================
# 0
# {'RoR': np.int64(0),
#  'STD': np.float64(0.0),
#  'SR': 0,
#  'VaR': np.float64(0.0),
#  'ToR': 0.0,
#  'returns': [0]}

# %%
# trader.fit()

# %%
# trader_test = DCTrader(
#     ticker='AAPL',
#     thresholds=thresholds,
#     strategies=strategies,
#     is_train=False,                 # No precomputar estados nuevos
#     start_date='2024-01-01',        # Periodo de test
#     end_date='2025-12-01'
# )

# trader_test.load_model()            # Cargar pesos entrenados

# %%
# # Celda 5: Backtest del ensemble y métricas básicas
# backtester = Backtest(trader_test)
# metrics_ensemble = backtester.run_ensemble()
# print("Métricas Ensemble:")
# metrics_ensemble

# %%
# Celda 6: Comparar varias estrategias (ensemble, buy&hold y algunas single)
# comparacion = backtester.compare_metrics([
#     'MSTGAM',
#     'buy_hold',
#     (2, 0),     # St3 con theta=0.01
#     (3, 1),     # St4 con theta=0.02
#     (0, 2),     # St1 con theta=0.015
# ])
# comparacion

# %%
# comparacion = backtester.plot_returns([
#     'MSTGAM',
#     'buy_hold',
#     (2, 0),     # St3 con theta=0.01
#     (3, 1),     # St4 con theta=0.02
#     (0, 2),     # St1 con theta=0.015
# ])
# comparacion

# %%
# # Celda 8: (Opcional) Probar una predicción single en un punto concreto
# t_test = 10  # día de prueba
# p_test = trader_test.prices.iloc[t_test]

# action_single = trader_test.predict_single(
#     t_current=t_test,
#     p_current=p_test,
#     strategy_idx=2,      # St3 (índice 2)
#     threshold_idx=0
# )

# print(f"Día {t_test} | Precio: {p_test:.2f}")
# print(f"Recomendación St3 (theta=0.01): {['Hold', 'Buy', 'Sell'][action_single]}")

# %%
# # Celda 9: (Opcional) Backtest rápido de una estrategia single
# metrics_st3 = backtester.run_single_strategy(strategy_idx=2, threshold_idx=0)
# print("Métricas St3 (theta=0.01):")
# metrics_st3
